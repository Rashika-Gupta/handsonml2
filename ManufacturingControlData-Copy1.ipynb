# %%
# %pip install seaborn
import os
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 1.7 MB/s eta 0:00:000:00:010:00:01:01
# ...
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
import math

# %%
df = pd.read_csv('./dataSet/train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900000 entries, 0 to 899999
# Data columns (total 33 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      900000 non-null  int64
#  1   f_00    900000 non-null  float64
#  2   f_01    900000 non-null  float64
#  3   f_02    900000 non-null  float64
#  4   f_03    900000 non-null  float64
#  5   f_04    900000 non-null  float64
#  6   f_05    900000 non-null  float64
#  7   f_06    900000 non-null  float64
#  8   f_07    900000 non-null  int64
#  9   f_08    900000 non-null  int64
#  10  f_09    900000 non-null  int64
#  11  f_10    900000 non-null  int64
#  12  f_11    900000 non-null  int64
#  13  f_12    900000 non-null  int64
#  14  f_13    900000 non-null  int64
#  15  f_14    900000 non-null  int64
#  16  f_15    900000 non-null  int64
#  17  f_16    900000 non-null  int64
#  18  f_17    900000 non-null  int64
#  19  f_18    900000 non-null  int64
# ...

# %% [markdown]
# There are 900,000 rows (instances) with 30 features and one target variable
# 1. There is also no null value.
# 2.One object dtype (maybe no categorical).

# %%
df. head()
# Out:
#    id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0   0 -1.373246  0.238887 -0.243376  0.567405 -0.647715  0.839326  0.113133
# 1   1  1.697021 -1.710322 -2.230332 -0.545661  1.113173 -1.552175  0.447825
# 2   2  1.681726  0.616746 -1.027689  0.810492 -0.609086  0.113965 -0.708660
# 3   3 -0.118172 -0.587835 -0.804638  2.086822  0.371005 -0.128831 -0.282575
# 4   4  1.148481 -0.176567 -0.664871 -1.101343  0.467875  0.500117  0.407515
#
#    f_07  f_08  ...      f_22      f_23      f_24      f_25      f_26  \
# 0     1     5  ... -2.540739  0.766952 -2.730628 -0.208177  1.363402
# 1     1     3  ...  2.278315 -0.633658 -1.217077 -3.782194 -0.058316
# 2     1     0  ... -1.385775 -0.520558 -0.009121  2.788536 -3.703488
# 3     3     2  ...  0.572594 -1.653213  1.686035 -2.533098 -0.608601
# 4     3     3  ... -3.912929 -1.430366  2.127649 -3.306784  4.371371
#
#          f_27        f_28  f_29  f_30  target
# 0  ABABDADBAB   67.609153     0     0       0
# ...

# %% [markdown]
# f_27 has alphabet (which might have been converted to the integer)

# %%
df.describe()
# Out:
#                   id           f_00           f_01           f_02  \
# count  900000.000000  900000.000000  900000.000000  900000.000000
# mean   449999.500000      -0.000286       0.001165       0.001174
# std    259807.765473       0.998888       0.999193       1.000514
# min         0.000000      -4.599856      -4.682199      -4.642676
# 25%    224999.750000      -0.675490      -0.675162      -0.674369
# 50%    449999.500000       0.001144       0.002014       0.002218
# 75%    674999.250000       0.674337       0.675021       0.677505
# max    899999.000000       4.749301       4.815699       4.961982
#
#                 f_03           f_04           f_05           f_06  \
# count  900000.000000  900000.000000  900000.000000  900000.000000
# mean       -0.001368      -0.000571       0.000284      -0.000709
# std         1.000175       1.000167       0.999875       0.999942
# min        -4.658816      -4.748501      -4.750214      -4.842919
# ...

# %% [markdown]
# Missing Data- heat map wil help in visualising what features are missinfg

# %%
df.shape #it is A 900, 000 by 33 matrix with 33 cols
# Out:
# (900000, 33)

# %%
sns.heatmap(df.isna(), yticklabels=False, cbar= False, cmap = 'tab20c_r')
plt.title('Missing Data')
plt.show()

# %% [markdown]
# There is no NaN value

# %%
df.dtypes['f_29']
sns.cou
# Out:
# dtype('int64')

# %%
#Defining a function to plot 
def PlotVar(dataset, cols = 5) :
    plt.style.use('seaborn-whitegrid')
    fig = plt.figure()
    rows = math.ceil(dataset.shape[1]/cols)
    for i, col in enumerate(dataset.columns): #not adding enumerate to see the effect later
        ax = fig.add_subplot(rows, cols, i + 1) 
        ax.set_title(col)
        if dataset.dtypes[col]== object:
            sns.countplot(y=col, data=dataset)
        else:
            sns.distplot(dataset[col])
PlotVar(df, cols = 3)

# %%
df.

# %%
rows, cols = 3,2
fig, ax = plt.subplots(rows, cols)
 
for row in range(rows):
    for col in range(cols):
        idx = 1+row + col
       # print(idx)
        ax[row,col].hist(df[idx])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12985/663204814.py in <module>
#       1 rows, cols = 3,2
# ----> 2 fig, ax = plt.subplots(rows, cols)
#       3
#       4 for row in range(rows):
#       5     for col in range(cols):
#
# NameError: name 'plt' is not defined

# %%
for i in df.columns:
    plt.figure()
    plt.title(f'{i}')
    plt.hist(df[i])
# Out:
# /home/rhythm/Research/ml/env/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Error in callback <function flush_figures at 0x7ff8a97ae488> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Research/ml/env/lib/python3.7/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ...
