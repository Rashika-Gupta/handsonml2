# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns

# %%
columns = ['KE', 'E1', 'E2', 't1', 't2', 'pze']
colName = ['TotalNoHits','KE', 'E1', 'E2', 't1', "t2", 'pInFoilz', 'pOutFoilz','pZe']
dtype = np.float16

# %% [markdown]
# # 6F6F-facing -z

# %%
minusZ6F6F0Foil = pd.read_csv('./sourcefacing-z/sixF-0Foil-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)
minusZ6F6F1Foil = pd.read_csv('./sourcefacing-z/sixF-1Foil-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)
minusZ6F6F2Foil = pd.read_csv('./sourcefacing-z/sixF-2Foil-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)

# %% [markdown]
# # 6F6F-facing +z

# %%
plusZ6F0Foil = pd.read_csv('./sourcefacing+z/sixF-0Foil-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)
plusZ6F1Foil = pd.read_csv('./sourcefacing+z/sixF-1Foil-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)
plusZ6F2Foil = pd.read_csv('./sourcefacing+z/sixF-2Foil-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)

# %% [markdown]
# # mylar-facing +z

# %%
plusZMyl0Foil = pd.read_csv('./sourcefacing+z/mylarFoil0-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)
plusZMyl1Foil = pd.read_csv('./sourcefacing+z/mylarFoil1-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)
plusZMyl2Foil = pd.read_csv('./sourcefacing+z/mylarFoil2-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)

# %% [markdown]
# ## foil in Bz

# %%
plusZMylFoilBz1 = pd.read_csv('../../may/foil-magExp-source+z/mylarFoil1-20Million-type1.txt',  sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz'], axis = 1)
plusZMylFoilBz2 = pd.read_csv('../../may/foil-magExp-source+z/mylar1Foil02-20Million-type1.txt',sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz'], axis = 1)
plusZMylFoilBz3 = pd.read_csv('../../may/foil-magExp-source+z/mylarFoil03-20Million-type1.txt', sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz'], axis = 1)
plusZMylFoilBz4 = pd.read_csv('../../may/foil-magExp-source+z/mylarFoil4-20Million-type1.txt',  sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz'], axis = 1)
plusZMylFoilBz5 = pd.read_csv('../../may/foil-magExp-source+z/mylar5Foil02-20Million-type1.txt',sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz'], axis = 1)
plusZMylFoilBz6 = pd.read_csv('../../may/foil-magExp-source+z/mylar1Foil06-20Million-type1.txt',sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz'], axis = 1)

# %%
plusZMylFoilBz1
# Out:
#               E1       E2            t1            t2
# 0       147.4400  214.720  9.925100e-08  4.596970e-08
# 1       246.2660  108.031  1.005770e-07  4.752850e-08
# 2       240.6290  121.650  1.171060e-08  4.712730e-08
# 3        56.4189  329.873  9.353440e-08  5.908920e-08
# 4       209.9700  152.490  9.929150e-08  1.306420e-07
# ...          ...      ...           ...           ...
# 361801  108.5630  275.260  9.929200e-08  5.069370e-08
# 361802  105.6840  276.795  2.145460e-07  1.601510e-07
# 361803   44.7015  311.118  2.319550e-07  1.268630e-07
# 361804  252.7790  100.574  6.344860e-08  4.195610e-08
# 361805  107.3380  254.899  4.226530e-08  1.454780e-08
#
# [361806 rows x 4 columns]

# %%
plusBz={
"01": plusZMylFoilBz1,
"02": plusZMylFoilBz2, 
"03": plusZMylFoilBz3,
"04": plusZMylFoilBz4, 
"05": plusZMylFoilBz5, 
"06": plusZMylFoilBz6

}

# %% [markdown]
# # mylar- facing -z

# %%
minusZMyl0Foil = pd.read_csv('./sourcefacing-z/mylar-0Foil-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)
minusZMyl1Foil = pd.read_csv('./sourcefacing-z/mylar-1Foil-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)
minusZMyl2Foil = pd.read_csv('./sourcefacing-z/mylar-2Foil-20Million-type1.txt',sep = " ", header = None, dtype = dtype,names = columns)

# %% [markdown]
# ## foil in Bz

# %%
minusZMylFoilBz1 = pd.read_csv('../../may/foil-magExp-source-z/mylar-1Foil01-20Million-type1.txt',sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz', ], axis = 1)
minusZMylFoilBz2 =  pd.read_csv('../../may/foil-magExp-source-z/mylar1Foil02-20Million-type1.txt',sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz', ], axis = 1)
minusZMylFoilBz3 = pd.read_csv('../../may/foil-magExp-source-z/mylar-1Foil03-20Million-type1.txt',sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz', ], axis = 1)
minusZMylFoilBz4 = pd.read_csv('../../may/foil-magExp-source-z/mylar-1Foil04-20Million-type1.txt',sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz', ], axis = 1)
minusZMylFoilBz5 = pd.read_csv('../../may/foil-magExp-source-z/mylar-1Foil05-20Million-type1.txt',sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz', ], axis = 1)
minusZMylFoilBz6 =  pd.read_csv('../../may/foil-magExp-source-z/mylar1Foil06-20Million-type1.txt',sep = " ", header = None, names = colName).drop(['TotalNoHits', 'KE', 'pInFoilz', 'pOutFoilz', ], axis = 1)

# %%
minusZMylFoilBz1
# Out:
#               E1        E2            t1            t2
# 0       267.7900   93.5911  2.671600e-08  5.424080e-08
# 1       210.5060  150.6710  4.477320e-08  1.111010e-07
# 2       129.4510  231.5620  1.737900e-08  4.876890e-08
# 3       206.9560  149.1690  4.434320e-08  1.357530e-08
# 4       217.7790  141.2480  4.735350e-08  7.342520e-08
# ...          ...       ...           ...           ...
# 361387   79.2006  305.8950  7.157430e-08  1.679340e-08
# 361388  222.2120  130.1870  2.371420e-08  6.746770e-08
# 361389  107.5240  217.1790  1.565680e-08  1.546940e-07
# 361390  189.7290  148.9740  6.484830e-08  2.765470e-08
# 361391  333.9250   51.7676  1.803150e-08  5.315320e-08
#
# [361392 rows x 4 columns]

# %%
minusBz={"01": minusZMylFoilBz1, 
"02": minusZMylFoilBz2, 
"03": minusZMylFoilBz3, 
"04": minusZMylFoilBz4, 
"05": minusZMylFoilBz5, 
"06": minusZMylFoilBz6

}

# %% [markdown]
# ### Type 0 events

# %%
minusZMylFoilBz01 = pd.read_csv('../../may/foil-magExp-source-z/mylar-1Foil01-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)
minusZMylFoilBz02 = pd.read_csv('../../may/foil-magExp-source-z/mylar1Foil02-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)
minusZMylFoilBz03 = pd.read_csv('../../may/foil-magExp-source-z/mylar-1Foil03-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)

# %%
minusZMylFoilBz04 = pd.read_csv('../../may/foil-magExp-source-z/mylar-1Foil04-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)
minusZMylFoilBz05 = pd.read_csv('../../may/foil-magExp-source-z/mylar-1Foil05-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)
minusZMylFoilBz06 =  pd.read_csv('../../may/foil-magExp-source-z/mylarFoil06-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)

# %%
minusBzType0={"01": minusZMylFoilBz01, 
"02": minusZMylFoilBz02,
"03": minusZMylFoilBz03, 
"04": minusZMylFoilBz04,
"05": minusZMylFoilBz05,
"06": minusZMylFoilBz06

}

# %%
plusZMylFoilBz01 = pd.read_csv('../../may/foil-magExp-source+z/mylarFoil1-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)
plusZMylFoilBz02 = pd.read_csv('../../may/foil-magExp-source+z/mylar1Foil02-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)
plusZMylFoilBz03 = pd.read_csv('../../may/foil-magExp-source+z/mylarFoil03-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)
plusZMylFoilBz04 = pd.read_csv('../../may/foil-magExp-source+z/mylarFoil4-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)
plusZMylFoilBz05 = pd.read_csv('../../may/foil-magExp-source+z/mylar5Foil02-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)
plusZMylFoilBz06 = pd.read_csv('../../may/foil-magExp-source+z/mylar1Foil06-20Million-type0.txt',sep = " ", header = None, dtype = dtype,names = columns).drop(['KE', 't1', 't2', 'pze'], axis = 1)

# %%
plusZMylFoilBz01.head()
# Out:
#        E1      E2
# 0  361.75    0.00
# 1  361.75    0.00
# 2  362.75    0.00
# 3    0.00  359.25
# 4    0.00  361.75

# %%
plusBzType0={"01": plusZMylFoilBz01, 
"02": plusZMylFoilBz02,
"03": plusZMylFoilBz03, 
"04": plusZMylFoilBz04,
"05": plusZMylFoilBz05,
"06": plusZMylFoilBz06

}

# %%
plus = {"Type0" : plusBzType0, "Type1" : plusBz}
minus = {"Type0" : minusBzType0 , "Type1" : minusBz}

# %%
source['plus']['Type0'].keys()
# Out:
# dict_keys(['01', '02', '03', '04', '05', '06'])

# %%
source = {
"plus" : plus,
"minus" : minus,    
}

# %% [markdown]
# # Functions

# %% [markdown]
# ## tot counts Type 1

# %%
def nCountsDet ( source ,df, Type, tDet1, tDet2, det1, det2, Ecut):
    
    if source == 'plus' :
        if det1 == 'E1':
            detF = 'E1'
        elif det1 == 'E2': 
            detF  =  'E2'
            Ecut = 0 
    elif source =='minus':
        if det1 == 'E2':
            detF = 'E2'
        elif det1 == 'E1': 
            detF = 'E1'
            Ecut = 0            
    df = df[df[det1] > Ecut]
        
    if Type > 0 :
        df = df[df[tDet1] < df[tDet2]]
    else : 
        df = df[(df[det1] != 0) & (df[det2] == 0)]
    n = df.shape[0] # total count
    return n

# %% [markdown]
# ## Ratio and Error

# %%
# no array for energy cuts yet 01/05
def ratioErr(N1, N0):
    #ratio = []
   
    #err = []
    #for i in range(len(N0)):
    #    result_inner_list = []
    #    err_inner_list = []
    #    for j in range(len(N0[i])):
    #        frac = N1[i][j] / N0[i][j]
    #        result_inner_list.append(frac)
    #        error = frac*(np.sqrt((1/N1[i][j])+(1/N0[i][j])))
    #        err_inner_list.append(error)
      #  frac = N1[i]/N0[i]
      #  error = frac*(np.sqrt((1/N1[i])+(1/N0[i])))
    frac = N1/N0
    error = frac*(np.sqrt((1/N1)+(1/N0)))
      
        #ratio.append(result_inner_list)
       # err.append(err_inner_list)
    return frac, error

# %% [markdown]
# ## Tot Counts type 0

# %%
def nCountsDetType0 (df, det1, det2, Ecut,det):
    df = df[df[det] > Ecut]
    df = df[(df[det1] != 0) &  (df[det2]==0)]
    n = df.shape[0] # total count
    return n

# %% [markdown]
# ## plotting - ratio

# %%
configs = ['0 Foil', '1 Foil', '2 Foils']

# %%
def plotFunc(R1, R2, errR1, errR2, title ):
    plt.figure(figsize=(10,8))
    plt.errorbar(y = R1, x = configs, yerr = errR1,fmt = 'o', c = 'red',label = 'detector 1')
    plt.errorbar(y = R2, x = configs, yerr = errR2,fmt = 'o', c = 'blue',label = 'detector 2')
    plt.xticks(fontsize = 14)
    plt.ylim(0.0175, 0.020)
    plt.yticks(fontsize = 16)
    plt.grid(which='both', linestyle = '--')
    plt.title(f'Change in Ratio for {str(title)}', fontsize = 16)
    plt.legend()
    plt.ylabel(r'$\frac{N_{Type 1}}{N_{Type 0}}$', fontsize = 16)
    plt.xlabel('Configurations ', fontsize = 16)
    plt.tight_layout()
    #plt.savefig('./changeInRatio'+str(foilN)+'foilSH'+a+'.png')
    return plt.show()

# %% [markdown]
# ## avgX vs Y

# %%
def avgXavgY(df, X, Y, tFirst, tLast, nBins, minRange, maxRange, Ecut, detTrig,) :
    if Ecut != 0 :
        df = df[df[detTrig] > Ecut]
        df = df[df[tFirst]<df[tLast]]
    df['etof'] = df[tLast]-df[tFirst]
    mean_stat  = scipy.stats.binned_statistic(x = df[X], values = df[Y], statistic='mean', bins = nBins, range = (minRange,maxRange))
    count_stat = scipy.stats.binned_statistic(x = df[X], values = df[Y], statistic='count', bins = nBins, range = (minRange,maxRange))
    xEdge = mean_stat.bin_edges[1:]
    yMean = mean_stat.statistic
    yCount = count_stat.statistic
    yStd = yMean/np.sqrt(yCount)
    return xEdge, yMean, yStd, yCount

# %% [markdown]
# ## total number of hits

# %%
def plotTotNoHits(df, col, title) : 
    df['etof'] = abs(df['t1'] - df['t2'])
    df['DurationOfEtof'] = np.where(df['etof'] < 20e-09, 'small', 
                          np.where(df['etof'] > 200e-09, 'large', ''))
    plt.figure(figsize=(10,8))
    sns.histplot(data=df, x= col, hue='DurationOfEtof', log_scale=(False, True), multiple='stack')
    plt.title('Total Number of hits for backscattered Events'+str(title), fontsize = 16)
    plt.xlabel(col, fontsize = 14)
    plt.xticks(np.arange(0,12,1),fontsize = 14)
    plt.yticks(fontsize = 14)
    plt.ylabel('Counts', fontsize = 14)
    plt.grid(linestyle = '--')
    plt.savefig('../../may/foil-magExp-source+z/TotHitsCount'+str(title)+'.png')
    return plt.show()

# %% [markdown]
# ## plotting x-y

# %%
def plotAvgXavgY(dfDictE1, dfDictE2, title, ylabel ) :
    foilName=list(dfDictE1.keys())
    x10, y10, erry10, _ = dfDictE1[foilName[0]]
    x11, y11, erry11, _ = dfDictE1[foilName[1]]
    x12, y12, erry12, _ = dfDictE1[foilName[2]]

    x20, y20, erry20, _ = dfDictE2[foilName[0]]
    x21, y21, erry21, _ = dfDictE2[foilName[1]]
    x22, y22, erry22, _ = dfDictE2[foilName[2]]

    plt.figure(figsize=(14,10))

    plt.errorbar(x = x10, y = y10,yerr=erry10,label = 'foil 0 E1',c = 'red', fmt = 'x')
    plt.errorbar(x = x11, y = y11,yerr=erry11,label = 'foil 1 E1',c = 'blue', fmt = 'x')
    plt.errorbar(x = x12, y = y12,yerr=erry12,label = 'foil 2 E1',c = 'green', fmt = 'x')
    plt.errorbar(x = x20, y = y20,yerr=erry20,label = 'foil 0 E2', alpha = 0.7,c = 'red', fmt = 'o')
    plt.errorbar(x = x21, y = y21,yerr=erry21,label = 'foil 1 E2', alpha = 0.7,c = 'blue', fmt = 'o')
    plt.errorbar(x = x22, y = y22,yerr=erry22,label = 'foil 2 E2', alpha = 0.7,c = 'green', fmt = 'o')
    
    #   plt.ylim(-0.5, 0.5)
    plt.grid(linestyle = '--')

    plt.legend()
    plt.xlim(0,260e-09)
    plt.xlabel('etof(s)', fontsize = 14)
    plt.ylabel('Energy (keV)', fontsize = 14)
    # plt.ylabel(r'$\cos(\theta)$', fontsize = 14)
    plt.ylabel(ylabel, fontsize = 15)
       # plt.ylim(0.0,0.6)  
    plt.yticks(fontsize = 16)
    plt.xticks(np.arange(0,260e-09, 25e-09),fontsize = 16)
    # plt.title(r'Variation in $\cos(\theta)$ with tof for Mylar source E_cut'+str(i)+'keV (det1 triggered first) ', fontsize = 16)
    plt.title(title, fontsize = 16)
    
  #  plt.savefig('./etofVSenergysixFsixFdet1'+str(i)+'.png')
    return plt.show()

# %% [markdown]
# ## plotting foils separately for Ecuts too

# %%
def plotFoilsAvg (df1, Y1,  Y2, tFirst, tLast, EcutValue, detTrigg, yMin1, yMin2, title, yLabel):

    colors = ['blue', 'orange', 'green', 'red', 'purple', 'gray']
    labels= ['foil at z =1.6m ','foil at z = 1.7 m', 'foil at z = 1.8 m', 'foil at z = 1.9 m', 'foil at z = 2.0 m', 'foil at z = 2.1 m', 
    ]
    for i,( key, value) in enumerate(df1.items()):
        x, y, ystd, _ = avgXavgY(value, 'etof', Y1, tFirst, tLast, 25, 0e-09, 250e-09, EcutValue, detTrigg)
       # x1, y2, ystd2, _ = avgXavgY(value, 'etof', Y2, tFirst, tLast, 25, 0e-09, 250e-09, EcutValue, detTrigg)
        fig, ax = plt.subplots(figsize=(12, 10))
        plt.xticks(np.arange(0,260e-09, 20e-09),fontsize=16)
        plt.yticks(fontsize=16)    
        plt.xlabel('etof(s)', fontsize=16)
        plt.ylabel(yLabel, fontsize=16)
        plt.title('pitch angular distribution when for source facing '+str(title)+str(EcutValue)+ ' (kev)', fontsize=14)
        plt.grid(linestyle='--')
        plt.ylim(yMin1, yMin2)
        plt.errorbar(x, y, yerr=ystd, fmt = 'o', color = colors[i], label=labels[i])
        #plt.errorbar(x1, y2, yerr=ystd2, fmt = 'x', color = colors[i])
        plt.fill_between(x,    y-ystd,   y+ystd, color = colors[i],alpha=0.1)
        #plt.fill_between(x1, y2-ystd2, y2+ystd2, color = colors[i],alpha=0.1)
        plt.legend(fontsize = 16)
        plt.tight_layout()
        plt.savefig('../../may/FoilMovedBzsource-zat'+str(yLabel)+str(i)+str( EcutValue)+str(title)+'(keV).png')
       # plt.show()

# %%
def plotFoilsAvg (df1,df2, Y1,  Y2, tFirst, tLast, tFirst1, tLast1, EcutValue, detTrigg, yMin1, yMin2, title, yLabel,detTrigg1, i, j):

    colors = ['blue', 'orange', 'green', 'red', 'purple', 'gray']
    labels= ['foil at z =1.6m ','foil at z = 1.7 m', 'foil at z = 1.8 m', 'foil at z = 1.9 m', 'foil at z = 2.0 m', 'foil at z = 2.1 m', 
    ]
    
    x1, y1, ystd1, _ = avgXavgY(df1, 'etof', Y1, tFirst, tLast, 20, 0e-09, 250e-09, EcutValue, detTrigg)
    x2, y2, ystd2, _ = avgXavgY(df1, 'etof', Y2, tFirst, tLast, 20, 0e-09, 250e-09, EcutValue, detTrigg)
    x3, y3, ystd3, _ = avgXavgY(df2, 'etof', Y1, tFirst1, tLast1, 20, 0e-09, 250e-09, EcutValue, detTrigg1)
    x4, y4, ystd4, _ = avgXavgY(df2, 'etof', Y2, tFirst1, tLast1, 20, 0e-09, 250e-09, EcutValue, detTrigg1)
    
    fig, ax = plt.subplots(figsize=(12, 10))
    plt.xticks(np.arange(0,260e-09, 20e-09),fontsize=16)
    plt.yticks(fontsize=16)    
    plt.xlabel('etof(s)', fontsize=16)
    plt.ylabel(yLabel, fontsize=16)
    plt.title(f'{str(yLabel)} vs tof {str(title)} {str(EcutValue)} (kev)', fontsize=14)
    plt.grid(linestyle='--')
    plt.ylim(yMin1, yMin2)
    plt.errorbar(x1, y1, yerr = ystd1, fmt = 'o', color = colors[i], label='source +z')
    plt.errorbar(x2, y2, yerr = ystd2, fmt = 'x', color = colors[i] )
    plt.errorbar(x3, y3, yerr = ystd3, fmt = 'o', color = colors[j], label='source -z')
    plt.errorbar(x4, y4, yerr = ystd4, fmt = 'x', color = colors[j])
    plt.fill_between(x1, y1-ystd1, y1+ystd1, color = colors[i],alpha=0.1)
    plt.fill_between(x2, y2-ystd2, y2+ystd2, color = colors[i],alpha=0.1)
    plt.fill_between(x3, y3-ystd3, y3+ystd3, color = colors[j],alpha=0.1)
    plt.fill_between(x4, y4-ystd4, y4+ystd4, color = colors[j],alpha=0.1)
    
    plt.legend(fontsize = 16)
    plt.tight_layout()
    plt.savefig('../../may/FoilMovedBzsource-'+str(yLabel)+str(i)+str( EcutValue)+str(title)+'(keV).png')
    plt.show()

# %%
plusBz.keys()
# Out:
# dict_keys(['01', '02', '03', '04', '05', '06'])

# %%
fig, ax = plt.subplots(figsize=(12, 10))
plt.xticks(fontsize= 16)
plt.yticks(fontsize =16)
plt.title('Pitch Angle Distribution foils in diff mag-field', fontsize = 16)
plt.ylabel('Probability',fontsize = 14)
plt.xlabel('pitch angle',fontsize = 14)
labels = ['z = 1.6 m','z = 1.7 m','z = 1.8 m','z = 1.9 m', 'z = 2.0 m', 'z = 2.1 m' ]
for i,( key, value )in enumerate(plusBz.items()):
    x = plusBz[key][plusBz[key].t1 < plusBz[key].t2]
    print(labels[i])
    #print(x.shape)
    #print(plusBz[key].shape)  
    sns.histplot(x.pZe, stat='probability', fill=False, element='step', log_scale= (False, True), label=labels[i])
#plt.grid(which= 'both', linestyle = '--')
plt.legend()
# Out:
# z = 1.6 m
# z = 1.7 m
# z = 1.8 m
# z = 1.9 m
# z = 2.0 m
# z = 2.1 m

# %%
fig, ax = plt.subplots(figsize=(12, 10))
plt.xticks(fontsize= 16)
plt.yticks(fontsize =16)
plt.title('Pitch Angle Distribution foils in diff mag-field source facing -z', fontsize = 16)
plt.ylabel('Probability',fontsize = 14)
plt.xlabel('pitch angle',fontsize = 14)
labels = ['z = 1.6 m','z = 1.7 m','z = 1.8 m','z = 1.9 m', 'z = 2.0 m', 'z = 2.1 m' ]
for i,( key, value )in enumerate(minusBz.items()):
    x = minusBz[key][minusBz[key].t2 < minusBz[key].t1]
    print(labels[i])
    #print(x.shape)
    #print(plusBz[key].shape)  
    sns.histplot(x.pZe, stat='probability', fill=False, element='step', log_scale= (False, True), label=labels[i])
#plt.grid(which= 'both', linestyle = '--')
plt.legend()
# Out:
# z = 1.6 m
# z = 1.7 m
# z = 1.8 m
# z = 1.9 m
# z = 2.0 m
# z = 2.1 m

# %% [markdown]
# # Variables

# %%
mylarMinusz = {'0FoilMinusZ' : minusZMyl0Foil,
'1FoilMinusZ' : minusZMyl1Foil,
'2FoilMinusZ' : minusZMyl2Foil, }

# %%
mylarPlusz = {'0FoilPlusZ' : plusZMyl0Foil,
'1FoilPlusZ' : plusZMyl1Foil,
'2FoilPlusZ' : plusZMyl2Foil, }

# %% [markdown]
# ## Ncounts

# %% [markdown]
# ### Mylar -z

# %% [markdown]
# since the source is fazing -z it would make m ore sense to look at the events that hit detector 2 places at -z first and then the events that hit detctor 1 i.e t2<t1

# %%
NminusZMyl0Foildet2 = nCountsDet(minusZMyl0Foil, 't2', 't1', 'E2', 0) #No Energy cut
NminusZMyl1Foildet2 = nCountsDet(minusZMyl1Foil, 't2', 't1', 'E2', 0) #No Energy cut
NminusZMyl2Foildet2 = nCountsDet(minusZMyl2Foil, 't2', 't1', 'E2', 0) #No Energy cut

# %%
NminusZMyl0Foildet1 = nCountsDet(minusZMyl0Foil, 't1', 't2', 'E2', 0) #No Energy cut
NminusZMyl1Foildet1 = nCountsDet(minusZMyl1Foil, 't1', 't2', 'E2', 0) #No Energy cut
NminusZMyl2Foildet1 = nCountsDet(minusZMyl2Foil, 't1', 't2', 'E2', 0) #No Energy cut

# %%
print('nMyl 0Foil Type11 : ', NminusZMyl0Foildet1)
print('nMyl 1Foil Type11 : ', NminusZMyl1Foildet1)
print('nMyl 2Foil Type11 : ', NminusZMyl2Foildet1)
print('nMyl 0Foil Type12 : ', NminusZMyl0Foildet2)
print('nMyl 1Foil Type12 : ', NminusZMyl1Foildet2)
print('nMyl 2Foil Type12 : ', NminusZMyl2Foildet2)
# Out:
# nMyl 0Foil Type11 :  175377
# nMyl 1Foil Type11 :  173578
# nMyl 2Foil Type11 :  179674
# nMyl 0Foil Type12 :  2838
# nMyl 1Foil Type12 :  186448
# nMyl 2Foil Type12 :  187053

# %%
#Type 0 mylar, facing -z
NFoil001mylar =  9544121
NFoil101mylar =  9494616
NFoil201mylar =  9381913
NFoil002mylar =  10256534
NFoil102mylar =  10126083
NFoil202mylar =  10217735

# %% [markdown]
# ### mylar +z

# %%
NPlusZMyl0Foildet2 = nCountsDet(plusZMyl0Foil, 't2', 't1', 'E2', 0) #No Energy cut
NPlusZMyl1Foildet2 = nCountsDet(plusZMyl1Foil, 't2', 't1', 'E2', 0) #No Energy cut
NPlusZMyl2Foildet2 = nCountsDet(plusZMyl2Foil, 't2', 't1', 'E2', 0) #No Energy cut
NPlusZMyl0Foildet1 = nCountsDet(plusZMyl0Foil, 't1', 't2', 'E2', 0) #No Energy cut
NPlusZMyl1Foildet1 = nCountsDet(plusZMyl1Foil, 't1', 't2', 'E2', 0) #No Energy cut
NPlusZMyl2Foildet1 = nCountsDet(plusZMyl2Foil, 't1', 't2', 'E2', 0) #No Energy cut

# %%
#Type 0 numbers :
NFoil001MylarPlusz =  10065813
NFoil101MylarPlusz =  9855991   
NFoil201MylarPlusz =  9703155   
NFoil002MylarPlusz =  9712226   
NFoil102MylarPlusz =  9761242   
NFoil202MylarPlusz =  9903260

# %% [markdown]
# ## Ratios

# %%
nType11MylarMinusZ = [NminusZMyl0Foildet1, NminusZMyl1Foildet1, NminusZMyl2Foildet1]
nType12MylarMinusZ = [NminusZMyl0Foildet2, NminusZMyl1Foildet2, NminusZMyl2Foildet2]
nType01MylarMinusZ = [NFoil001mylar, NFoil101mylar, NFoil201mylar]
nType02MylarMinusZ = [NFoil002mylar, NFoil102mylar, NFoil202mylar]

# %%
print('nType11MylarMinusZ : ', nType11MylarMinusZ) 
print('nType01MylarMinusZ : ', nType01MylarMinusZ) 
print('nType02MylarMinusZ : ', nType02MylarMinusZ) 
print('nType12MylarMinusZ : ', nType12MylarMinusZ)
# Out:
# nType11MylarMinusZ :  [175377, 173578, 179674]
# nType01MylarMinusZ :  [9544121, 9494616, 9381913]
# nType02MylarMinusZ :  [10256534, 10126083, 10217735]
# nType12MylarMinusZ :  [2838, 186448, 187053]

# %% [markdown]
# when the source is -z we observe
# * Type 01 < Type 02 and Type01 decreases with increase in number foil while Type 02 remains somewhat the same except that it decreases and then increases
# * Type 11 < Type 12 when there are foils when no foil Type12 < Type 11 by ~170000 but should one see this magneficient effect just because of the mylar which is 0.5 micron thickness.
#
# To check this should compare this with the 6F6F lower thickness should not lead to a lot of scattering.
# 2. the number should be same for N12 and N11 when source holder is at +z with N12 and N11 reversed

# %%
fracMylarMinuszDet1, errFracMylarMinuszDet1 = ratioErr(N1 = nType11MylarMinusZ, N0 = nType01MylarMinusZ)
fracMylarMinuszDet2, errFracMylarMinuszDet2 = ratioErr(N1 = nType12MylarMinusZ, N0 = nType02MylarMinusZ)

# %%
nType11MylarPlusZ = [NPlusZMyl0Foildet1, NPlusZMyl1Foildet1, NPlusZMyl2Foildet1]
nType12MylarPlusZ = [NPlusZMyl0Foildet2, NPlusZMyl1Foildet2, NPlusZMyl2Foildet2]
nType01MylarPlusZ = [NFoil001MylarPlusz, NFoil101MylarPlusz, NFoil201MylarPlusz]
nType02MylarPlusZ = [NFoil002MylarPlusz, NFoil102MylarPlusz, NFoil202MylarPlusz]

# %%
print('nTypeMylar11PlusZ : ',nType11MylarPlusZ )
print('nTypeMylar12PlusZ : ',nType12MylarPlusZ )
print('nTypeMylar02PlusZ : ',nType02MylarPlusZ )
print('nTypeMylar01PlusZ : ',nType01MylarPlusZ )
# Out:
# nTypeMylar11PlusZ :  [191215, 185277, 190130]
# nTypeMylar12PlusZ :  [3968, 175342, 177756]
# nTypeMylar02PlusZ :  [9712226, 9761242, 9903260]
# nTypeMylar01PlusZ :  [10065813, 9855991, 9703155]

# %%
fracMylarPluszDet1, errFracMylarPluszDet1 = ratioErr(N1 = nType11MylarPlusZ, N0 = nType01MylarPlusZ)
fracMylarPluszDet2, errFracMylarPluszDet2 = ratioErr(N1 = nType12MylarPlusZ, N0 = nType02MylarPlusZ)

# %%
print('fracMinuszDet1 : ', fracMylarMinuszDet1)
print('fracMinuszDet2 : ', fracMylarMinuszDet2)
print('fracPluszDet2 : ', fracMylarPluszDet2)
print('fracPluszDet1 : ', fracMylarPluszDet1)
# Out:
# fracMinuszDet1 :  [0.018375395701709984, 0.01828172935061302, 0.01915110489726349]
# fracMinuszDet2 :  [0.00027670166159445285, 0.01841264781258459, 0.01830669908742006]
# fracPluszDet2 :  [0.0004085572143811316, 0.01796308297653106, 0.017949240957018196]
# fracPluszDet1 :  [0.018996478476204556, 0.018798414081344028, 0.01959465761394103]

# %% [markdown]
# ### 6F6F at -z

# %%
NminusZ6F6F0Foildet2 = nCountsDet(minusZ6F6F0Foil, 't2', 't1', 'E2', 0) #No Energy cut
NminusZ6F6F1Foildet2 = nCountsDet(minusZ6F6F1Foil, 't2', 't1', 'E2', 0) #No Energy cut
NminusZ6F6F2Foildet2 = nCountsDet(minusZ6F6F2Foil, 't2', 't1', 'E2', 0) #No Energy cut

NminusZ6F6F0Foildet1 = nCountsDet(minusZ6F6F0Foil, 't1', 't2', 'E2', 0) #No Energy cut
NminusZ6F6F1Foildet1 = nCountsDet(minusZ6F6F1Foil, 't1', 't2', 'E2', 0) #No Energy cut
NminusZ6F6F2Foildet1 = nCountsDet(minusZ6F6F2Foil, 't1', 't2', 'E2', 0) #No Energy cut

# %%
print('n6F6F 0Foil Type11 : ', NminusZ6F6F0Foildet1)
print('n6F6F 1Foil Type11 : ', NminusZ6F6F1Foildet1)
print('n6F6F 2Foil Type11 : ', NminusZ6F6F2Foildet1)
print('n6F6F 0Foil Type12 : ', NminusZ6F6F0Foildet2)
print('n6F6F 1Foil Type12 : ', NminusZ6F6F1Foildet2)
print('n6F6F 2Foil Type12 : ', NminusZ6F6F2Foildet2)
# Out:
# n6F6F 0Foil Type11 :  181061
# n6F6F 1Foil Type11 :  174329
# n6F6F 2Foil Type11 :  177322
# n6F6F 0Foil Type12 :  181290
# n6F6F 1Foil Type12 :  183553
# n6F6F 2Foil Type12 :  182237

# %% [markdown]
# ## avgE vs tof

# %% [markdown]
# ### mylar -z

# %% [markdown]
# energy deposition in detector 1 and 2 when detector 2 gets triggered first

# %%
mylarE1vsTOFDet2 = {}
for dfName, df in mylarMinusz.items(): #looping through the dfs in mylar foils
    mylarE1vsTOFDet2[dfName] = {} 
    t, avgE1, errE1, nE1 = avgXavgY(df, X = 'etof', Y='E1',tFirst='t2',tLast='t1', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarE1vsTOFDet2[dfName]=( t, avgE1, errE1, nE1)

# %%
mylarE2vsTOFDet2 = {}
for dfName, df in mylarMinusz.items(): #looping through the dfs in mylar foils
    mylarE2vsTOFDet2[dfName] = {} 
    t, avgE1, errE1, nE1 = avgXavgY(df, X = 'etof', Y='E2',tFirst='t2',tLast='t1', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarE2vsTOFDet2[dfName]=( t, avgE1, errE1, nE1)

# %% [markdown]
# energy deposition in detector 1 and 2 when detector 1 gets triggered first

# %%
mylarE1vsTOFDet1 = {}
for dfName, df in mylarMinusz.items(): #looping through the dfs in mylar foils
    mylarE1vsTOFDet1[dfName] = {} 
    t, avgE1, errE1, nE1 = avgXavgY(df, X = 'etof', Y='E1',tFirst='t1',tLast='t2', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarE1vsTOFDet1[dfName]=( t, avgE1, errE1, nE1)

# %%
mylarE2vsTOFDet1 = {}
for dfName, df in mylarMinusz.items(): #looping through the dfs in mylar foils
    mylarE2vsTOFDet1[dfName] = {} 
    t, avgE1, errE1, nE1 = avgXavgY(df, X = 'etof', Y='E2',tFirst='t1',tLast='t2', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarE2vsTOFDet1[dfName]=( t, avgE1, errE1, nE1)

# %% [markdown]
# ### mylar+z

# %%
mylarPluszE1vsTOFDet2 = {}
for dfName, df in mylarPlusz.items(): #looping through the dfs in mylar foils
    mylarPluszE1vsTOFDet2[dfName] = {} 
    t, avgE1, errE1, nE1 = avgXavgY(df, X = 'etof', Y='E1',tFirst='t2',tLast='t1', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarPluszE1vsTOFDet2[dfName]=( t, avgE1, errE1, nE1)
# Out:
# /home/rhythm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
mylarPluszE2vsTOFDet2 = {}
for dfName, df in mylarPlusz.items(): #looping through the dfs in mylar foils
    mylarPluszE2vsTOFDet2[dfName] = {} 
    t, avgE1, errE1, nE1 = avgXavgY(df, X = 'etof', Y='E2',tFirst='t2',tLast='t1', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarPluszE2vsTOFDet2[dfName]=( t, avgE1, errE1, nE1)
# Out:
# /home/rhythm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
mylarPluszE1vsTOFDet1 = {}
for dfName, df in mylarPlusz.items(): #looping through the dfs in mylar foils
    mylarPluszE1vsTOFDet1[dfName] = {} 
    t, avgE1, errE1, nE1 = avgXavgY(df, X = 'etof', Y='E1',tFirst='t1',tLast='t2', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarPluszE1vsTOFDet1[dfName]=( t, avgE1, errE1, nE1)
# Out:
# /home/rhythm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
mylarPluszE2vsTOFDet1 = {}
for dfName, df in mylarPlusz.items(): #looping through the dfs in mylar foils
    mylarPluszE2vsTOFDet1[dfName] = {} 
    t, avgE1, errE1, nE1 = avgXavgY(df, X = 'etof', Y='E2',tFirst='t1',tLast='t2', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarPluszE2vsTOFDet1[dfName]=( t, avgE1, errE1, nE1)
# Out:
# /home/rhythm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## avge costh and tof

# %%
mylarcosthTOFDet2 = {}
for dfName, df in mylarMinusz.items(): #looping through the dfs in mylar foils
    mylarcosthTOFDet2[dfName] = {} 
    t, avgCosth, errCosth, n = avgXavgY(df, X = 'etof', Y='pze',tFirst='t2',tLast='t1', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarcosthTOFDet2[dfName]=( t, avgCosth, errCosth, n)
# Out:
# /home/rhythm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
mylarcosthTOFDet1 = {}
for dfName, df in mylarMinusz.items(): #looping through the dfs in mylar foils
    mylarcosthTOFDet1[dfName] = {} 
    t, avgCosth, errCosth, n = avgXavgY(df, X = 'etof', Y='pze',tFirst='t1',tLast='t2', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarcosthTOFDet1[dfName]=( t, avgCosth, errCosth, n)
# Out:
# /home/rhythm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
mylarPluscosthTOFDet1 = {}
for dfName, df in mylarPlusz.items(): #looping through the dfs in mylar foils
    mylarPluscosthTOFDet1[dfName] = {} 
    t, avgCosth, errCosth, n = avgXavgY(df, X = 'etof', Y='pze',tFirst='t1',tLast='t2', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarPluscosthTOFDet1[dfName]=( t, avgCosth, errCosth, n)
# Out:
# /home/rhythm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
mylarPluscosthTOFDet2 = {}
for dfName, df in mylarPlusz.items(): #looping through the dfs in mylar foils
    mylarPluscosthTOFDet2[dfName] = {} 
    t, avgCosth, errCosth, n = avgXavgY(df, X = 'etof', Y='pze',tFirst='t2',tLast='t1', nBins =25, minRange=0, maxRange = 250e-09 )
    mylarPluscosthTOFDet2[dfName]=( t, avgCosth, errCosth, n)
# Out:
# /home/rhythm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## field expansion region

# %% [markdown]
# ### ratios

# %% [markdown]
# -z

# %%
countsDiffCutsMinusBz = {}
for ECut in np.arange(0,100,10):
    for key, value in minusBz.items():
        N11 = nCountsDet(value, 't1', 't2', 'E1', ECut)
        N12 = nCountsDet(value, 't2', 't1', 'E2', ECut)
        if key not in countsDiffCutsMinusBz:
            countsDiffCutsMinusBz[key] = {}
        countsDiffCutsMinusBz[key][ECut] = {'N11': N11, 'N12': N12}

# %%
countsDiffCutsMinusBzType0 = {}
for ECut in np.arange(0,100,10):
    for key, value in minusBzType0.items():
        N01 = nCountsDetType0(value, 'E1', 'E2', ECut)
        N02 = nCountsDetType0(value, 'E2', 'E1', ECut)
        if key not in countsDiffCutsMinusBzType0:
            countsDiffCutsMinusBzType0[key] = {}
        countsDiffCutsMinusBzType0[key][ECut] = {'N1': N01, 'N2': N02}

# %%
countsDiffCutPlusBz = {}
for ECut in np.arange(0,100,10):
    for key, value in plusBz.items():
        N11 = nCountsDet(value, 't1', 't2', 'E1', ECut)
        N12 = nCountsDet(value, 't2', 't1', 'E2', ECut)
        if key not in countsDiffCutPlusBz:
            countsDiffCutPlusBz[key] = {}
        countsDiffCutPlusBz[key][ECut] = {'N11': N11, 'N12': N12}

# %%
countsDiffCutsPlusBzType0 = {}
for ECut in np.arange(0,100,10):
    for key, value in plusBzType0.items():
        N01 = nCountsDetType0(value, 'E1', 'E2', ECut,'E1')
        N02 = nCountsDetType0(value, 'E2', 'E1', ECut,'E2')
        if key not in countsDiffCutsPlusBzType0:
            countsDiffCutsPlusBzType0[key] = {}
        countsDiffCutsPlusBzType0[key][ECut] = {'N1': N01, 'N2': N02}

# %%
ratio =[]
err = []
for key_name in countsDiffCutsMinusBz.keys():
    n11 = countsDiffCutsMinusBz[key_name][30]['N11']
    n01 = countsDiffCutsMinusBzType0[key_name][30]['N1']
    x, y = ratioErr(n11,n01)
    ratio.append(x)
    err.append(y)

# %%
countsDiffCutsPlusBzType0

# %%
for E in np.arange(0,100,10):
    ratio =[]
    err = []
    ratio2 =[]
    err2 = []
    for key_name in countsDiffCutsPlusBzType0.keys():
        n11 = countsDiffCutPlusBz[key_name][E]['N11']
        n01 = countsDiffCutsPlusBzType0[key_name][E]['N1']
        x, y = ratioErr(n11,n01)

        n12 = countsDiffCutPlusBz[key_name][E]['N12']
        n02 = countsDiffCutsPlusBzType0[key_name][E]['N2']
        x2, y2 = ratioErr(n12, n02)
        ratio.append(x)
        err.append(y)
        ratio2.append(x2)
        err2.append(y2)
    plt.figure(figsize=(10,8))
    plt.errorbar(y = ratio,  x = np.arange(1,7,1), yerr = err, fmt = 'o', c = 'red', label = 'detector 1')
    plt.errorbar(y = ratio2, x = np.arange(1,7,1), yerr = err2,fmt = 'x', c = 'blue',label = 'detector 2')
    plt.fill_between(x=np.arange(1, 7, 1), y1=np.array(ratio)-np.array(err),  y2=np.array(ratio)+np.array(err), color = 'red', alpha = 0.1 )
    plt.fill_between(x=np.arange(1, 7, 1), y1=np.array(ratio2)-np.array(err2),y2=np.array(ratio2)+np.array(err2), color = 'blue',alpha = 0.1 )
    plt.ylabel(r'$\frac{N_{Type 1}}{N_{Type 0}}$', fontsize = 14)
    plt.xlabel(' foil at + *0.1(m)')
    plt.ylim(0.0165, 0.0195)
    plt.yticks(fontsize = 16)
    plt.xticks(fontsize = 14)
    plt.grid(which='both', linestyle = '--')
    plt.title('source facing +z Energy threshold : '+str(E), fontsize = 16  )
    plt.legend()
    plt.tight_layout()
    plt.savefig('./changeInRatio+zBothWShade'+str(E)+'.png')

# %%
plt.errorbar(x = np.arange(1,7,1), y = ratio, yerr=err, fmt = 'o')
plt.errorbar(x = np.arange(1,7,1), y = ratio2, yerr=err2, fmt = 'x' , color = 'red')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# +z

# %%
countsDiffCutsPlusBz = {}
for ECut in np.arange(0,100,10):
    for key, value in plusBz.items():
        N11 = nCountsDet(value, 't1', 't2', 'E1', ECut)
        N12 = nCountsDet(value, 't2', 't1', 'E2', ECut)
        if key not in countsDiffCutsPlusBz:
            countsDiffCutsPlusBz[key] = {}
        countsDiffCutsPlusBz[key][ECut] = {'N1': N11, 'N2': N12}

# %%
# Ecut 30 keV
# N for type 0 events, hitting detector 1 and position 1.6m 
N011 = nCountsDetType0(minusZMylFoilBz1, 'E1', 'E2')

# %% [markdown]
# # Plots

# %% [markdown]
# ## ratio

# %%
plotFunc(fracMylarMinuszDet1, fracMylarMinuszDet2,errFracMylarMinuszDet1, errFracMylarMinuszDet2, title ='Mylar sorce facing -z')

# %%
plotFunc(fracMylarPluszDet1, fracMylarPluszDet2,errFracMylarPluszDet1, errFracMylarPluszDet2, title ='Mylar source facing +z')

# %% [markdown]
# ## avgE

# %%
plotAvgXavgY(dfDictE1=mylarE1vsTOFDet2, dfDictE2=mylarE2vsTOFDet2, xTitle= 'at - z det 2 triggered first ')

# %%
plotAvgXavgY(dfDictE1=mylarPluszE1vsTOFDet1, dfDictE2=mylarPluszE2vsTOFDet1,xTitle= 'at +z det 1 triggered first' )

# %%
plotAvgXavgY(dfDictE1=mylarE1vsTOFDet1, dfDictE2=mylarE2vsTOFDet1, xTitle= 'at - z det 1 triggered first ')

# %%
plotAvgXavgY(dfDictE1=mylarPluszE1vsTOFDet2, dfDictE2=mylarPluszE2vsTOFDet2,xTitle= 'at +z det 2 triggered first' )

# %% [markdown]
# ## avd tof vs pze

# %%
plotAvgXavgY(dfDictE1=mylarPluscosthTOFDet1, dfDictE2=mylarPluscosthTOFDet2,title= 'pitch angle distribution for +z', ylabel= 'cos(theta)' )

# %%
plotAvgXavgY(dfDictE1=mylarcosthTOFDet1, dfDictE2=mylarcosthTOFDet2,title= 'pitch angle distribution for -z', ylabel= 'cos(theta)' )

# %% [markdown]
# ## total number of hits vs tof

# %%
for key, value in minusBz.items():
    plotTotNoHits(value, col = 'TotalNoHits', title = key)

# %% [markdown]
# ## pitch angle vs angle leaving the foil

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)    
plt.xlabel(r'$cos(\theta)_i$', fontsize=14)
plt.ylabel(r'$cos(\theta)_{out-foil}$', fontsize=14)
plt.title(r'Average $cos\theta$ of outgoing e- from foil when source is facing +z', fontsize=14)
plt.grid(linestyle='--')

for key, value in plusBz.items():
    x, y, ystd, _ = avgXavgY(value, 'pZe', 'pOutFoilz', 't1', 't2', 20, -1, 1, 0, 0)
    plt.errorbar(x, y, yerr=ystd, fmt = 'o', label=key)
    plt.fill_between(x, y-ystd, y+ystd, alpha=0.4)

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)    
plt.xlabel(r'$cos(\theta)_i$', fontsize=14)
plt.ylabel(r'$cos(\theta)_{out-foil}$', fontsize=14)
plt.title(r'Average $cos\theta$ of outgoing e- from foil when source is facing -z', fontsize=14)
plt.grid(linestyle='--')
labels= ['foil at z =1.6m ','foil at z = 1.7 m', 'foil at z = 1.8 m', 'foil at z = 1.9 m', 'foil at z = 2.0 m', 'foil at z = 2.1 m', 
]
for i,(key, value) in enumerate(minusBz.items()):
    x, y, ystd, _ = avgXavgY(value, 'pZe', 'pOutFoilz', 't1', 't2', 20, -1, 1, 0, 0)
    plt.errorbar(x, y, yerr=ystd, fmt = 'o', label=labels[i])
    plt.fill_between(x, y-ystd, y+ystd, alpha=0.4)

plt.legend()
plt.show()

# %% [markdown]
# ## EvsTof for diff zs

# %% [markdown]
# ### detector 1 triggered first

# %%
fig, ax = plt.subplots(figsize=(12, 10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)    
plt.xlabel('etof(s)', fontsize=14)
plt.ylabel('Energy  (keV)', fontsize=14)
plt.title('Change in energy desposition when detector 1 gets hits first source facing -z', fontsize=14)
plt.grid(linestyle='--')
plt.ylim(0, 325)
colors = ['blue', 'orange', 'green', 'red', 'pink', 'gray']
labels= ['foil at z =1.6m ','foil at z = 1.7 m', 'foil at z = 1.8 m', 'foil at z = 1.9 m', 'foil at z = 2.0 m', 'foil at z = 2.1 m', 
]
for i,( key, value) in enumerate(minusBz.items()):
    x, y, ystd, _ = avgXavgY(value, 'etof', 'E1', 't1', 't2', 25, 0e-09, 250e-09, 0, 0)
    x1, y2, ystd2, _ = avgXavgY(value, 'etof', 'E2', 't1', 't2', 25, 0e-09, 250e-09, 0, 0)
    
    plt.errorbar(x, y, yerr=ystd, fmt = 'o', color = colors[i], label=labels[i])
    plt.errorbar(x1, y2, yerr=ystd2, fmt = 'x', color = colors[i])
    plt.fill_between(x, y-ystd, y+ystd, alpha=0.1)
    plt.fill_between(x1, y2-ystd2, y2+ystd2, alpha=0.1)

plt.legend()
plt.savefig('../../may/EvsTofFoilMovedBzsource-z.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)    
plt.xlabel('etof(s)', fontsize=14)
plt.ylabel('Energy  (keV)', fontsize=14)
plt.title('Change in energy desposition when detector 1 gets hits first source facing +z', fontsize=14)
plt.grid(linestyle='--')
plt.ylim(0, 325)
colors = ['blue', 'orange', 'green', 'red', 'pink', 'gray']
labels= ['foil at z =1.6m ','foil at z = 1.7 m', 'foil at z = 1.8 m', 'foil at z = 1.9 m', 'foil at z = 2.0 m', 'foil at z = 2.1 m', 
]
for i,( key, value) in enumerate(plusBz.items()):
    x, y, ystd, _ = avgXavgY(value, 'etof', 'E1', 't1', 't2', 25, 0e-09, 250e-09, 0, 0)
    x1, y2, ystd2, _ = avgXavgY(value, 'etof', 'E2', 't1', 't2', 25, 0e-09, 250e-09, 0, 0)
    
    plt.errorbar(x, y, yerr=ystd, fmt = 'o', color = colors[i], label=labels[i])
    plt.errorbar(x1, y2, yerr=ystd2, fmt = 'x', color = colors[i])
    plt.fill_between(x, y-ystd, y+ystd, alpha=0.1)
    plt.fill_between(x1, y2-ystd2, y2+ystd2, alpha=0.1)

plt.legend()
plt.savefig('../../may/EvsTofFoilMovedBzsource+z.png')
plt.show()

# %%
colors = ['blue', 'orange', 'green', 'red', 'purple', 'gray']
labels= ['foil at z =1.6m ','foil at z = 1.7 m', 'foil at z = 1.8 m', 'foil at z = 1.9 m', 'foil at z = 2.0 m', 'foil at z = 2.1 m', 
]
for i,( key, value) in enumerate(plusBz.items()):
    x, y, ystd, _ = avgXavgY(value, 'etof', 'E1', 't1', 't2', 25, 0e-09, 250e-09, 0, 0)
    x1, y2, ystd2, _ = avgXavgY(value, 'etof', 'E2', 't1', 't2', 25, 0e-09, 250e-09, 0, 0)
    fig, ax = plt.subplots(figsize=(12, 10))
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)    
    plt.xlabel('etof(s)', fontsize=14)
    plt.ylabel('Energy  (keV)', fontsize=14)
    plt.title('Change in energy desposition when detector 1 gets hits first source facing +z', fontsize=14)
    plt.grid(linestyle='--')
    plt.ylim(0, 325)
    plt.errorbar(x, y, yerr=ystd, fmt = 'o', color = colors[i], label=labels[i])
    plt.errorbar(x1, y2, yerr=ystd2, fmt = 'x', color = colors[i])
    plt.fill_between(x,    y-ystd,   y+ystd, color = colors[i],alpha=0.1)
    plt.fill_between(x1, y2-ystd2, y2+ystd2, color = colors[i],alpha=0.1)
    plt.legend(fontsize = 14)
    plt.savefig('../../may/EvsTofFoilMovedBzsource+zat'+str(i)+'.png')
    plt.show()

# %%
# source facing -z hits detector 1 first
for EThr in np.arange(0,100,10):
    plotFoilsAvg(minusBz, 'E1', 'E2','t1', 't2', EThr, 'E1',0,375, '-zhits detector 1 first ', yLabel='Energy (keV)')

# %%
# source facing -z hits detector 2 first
for EThr in np.arange(0,100,10):
    plotFoilsAvg(minusBz, 'E1', 'E2', 't2', 't1', EThr, 'E2',0,375, '-z hits detector 2 first ', yLabel='Energy (keV)')

# %%
# source facing +z hits detector 1 first
for EThr in np.arange(0,100,10):
    plotFoilsAvg(plusBz, 'E1', 'E2', 't1', 't2', EThr, 'E1',0,375, '+z hits detector 1  first', yLabel='Energy (keV)')

# %%
# source facing +z hits detector 2 first
for EThr in np.arange(0,100,10):
    plotFoilsAvg(plusBz, 'E1', 'E2', 't2', 't1', EThr, 'E2',0,375, '+z hits detector 2 first', yLabel='Energy (keV)')

# %% [markdown]
# ## pitchAng Vs etof

# %%
# source facing -z hits detector 1 first
for EThr in np.arange(0,100,10):
    plotFoilsAvg(minusBz, 'pZe', 0,'t1', 't2', EThr, 'E1',-0.1,0.8, '-z hits detector 1 first ', yLabel=r'$cos\theta$')

# %%
# source facing -z hits detector 1 first
for EThr in np.arange(0,100,10):
    plotFoilsAvg(minusBz, 'pZe', 0,'t2', 't1', EThr, 'E2',-0.8,0.1, '-z hits detector 2 first ', yLabel=r'$cos\theta$')

# %%
# source facing -z hits detector 1 first
for EThr in np.arange(0,100,10):
    plotFoilsAvg(plusBz, 'pZe', 0,'t1', 't2', EThr, 'E1',-0.1,0.8, '+z hits detector 1 first ', yLabel=r'$cos\theta$')

# %%
# source facing +z hits detector 1 first
for EThr in np.arange(0,100,10):
    plotFoilsAvg(plusBz, 'pZe', 0,'t2', 't1', EThr, 'E2',-0.8,0.1, '+z hits detector 2 first ', yLabel=r'$cos\theta$')

# %%
source.keys()
# Out:
# dict_keys(['plus', 'minus'])

# %%
asymmetry_plus

# %% [markdown]
# ## ratio and asymmetry for both sources comparison

# %%
import matplotlib.pyplot as plt

#ratios2_plus = {}
#ratios2_minus = {}
for EThr in np.arange(30, 110, 20): 
    ratios_plus = {'Detector1': [], 'Detector2': []}
    ratios_minus = {'Detector1': [], 'Detector2': []}
    asymmetry_plus = {'asym' : [], 'errAsym': []}
    asymmetry_minus = {'asym' : [], 'errAsym': []}
    for key, value in source.items():
        print('------1------')
        print(key)
        
        nType1 = source[key]['Type1'] 
        nType0 = source[key]['Type0'] 
        for key1 in plusBzType0.keys():
            N01 = nCountsDet(source=key, Type = 0,df = nType0[key1], tDet1=0, tDet2 = 0, det1 = 'E1',det2 = 'E2',Ecut=EThr )        
            N02 = nCountsDet(source=key, Type = 0,df = nType0[key1], tDet1=0, tDet2 = 0, det1 = 'E2',det2 = 'E1',Ecut = EThr )
            N11 = nCountsDet(source=key, Type = 1,df = nType1[key1], tDet1 = 't1', tDet2 = 't2', det1 = 'E1',det2 = 'E2',Ecut=EThr )
            N12 = nCountsDet(source=key, Type = 1,df = nType1[key1], tDet1 = 't2', tDet2 = 't1', det1 = 'E2',det2 = 'E1',Ecut = EThr)        
            r1, er1 = ratioErr(N11, N01) 
            r2, er2 = ratioErr(N12, N02) 
            a = r1-r2
            erra = er1 + er2
            print(f'N01 : {N01} , N02 : {N02} ; N11 : {N11}, N12 : {N12}')
            print(f' Asymmety : {a}')

            if key == 'plus':
                ratios_plus['Detector1'].append((r1, er1))
                ratios_plus['Detector2'].append((r2, er2))
                asymmetry_plus['asym'].append(a)
                asymmetry_plus['errAsym'].append(erra)
                
            elif key == 'minus':
                ratios_minus['Detector1'].append((r1, er1))
                ratios_minus['Detector2'].append((r2, er2))
                asymmetry_minus['asym'].append(a)
                asymmetry_minus['errAsym'].append(erra)
                
    plt.figure(figsize=(12,8))
    plt.xlim(0,7)
    plt.ylim(-0.0010, 0.0010)
    plt.xlabel(' Foil position ', fontsize = 14)
    plt.ylabel(r'$r_1 - r2$', fontsize = 14)
    plt.title(f'Ratio variation with change in EThreshold = {str(EThr)} (keV)', fontsize = 16)
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
#   # for det in ['Detector1', 'Detector2']:
    plt.errorbar(x = np.arange(1,7, 1), y =  asymmetry_plus['asym'] , yerr=asymmetry_plus['errAsym'] , fmt = 'o', label="source +z")
    plt.errorbar(x = np.arange(1,7, 1), y =  asymmetry_minus['asym'] , yerr=asymmetry_minus['errAsym'] , fmt = 'o', label="source -z")
    plt.fill_between(x = np.arange(1,7,1), y1=np.array(asymmetry_plus['asym'])-np.array(asymmetry_plus['errAsym']), y2=np.array(asymmetry_plus['asym'])+np.array(asymmetry_plus['errAsym']), alpha = 0.1)
    
    plt.fill_between(x = np.arange(1,7,1),  y1=np.array(asymmetry_minus['asym'])-np.array(asymmetry_minus['errAsym']),y2=np.array(asymmetry_minus['asym'])+np.array(asymmetry_minus['errAsym']),alpha = 0.1)
    plt.grid(which = 'both', linestyle = '--')    
    plt.legend()
    plt.savefig(f'../../may/changeInAsym{str(EThr)}.png')
    plt.show()
#
# Out:
# ------1------
# plus
# N01 : 10069522 , N02 : 9549812 ; N11 : 186359, N12 : 172252
#  Asymmety : 0.0004700202908540889
# N01 : 10032933 , N02 : 9524379 ; N11 : 187804, N12 : 172670
#  Asymmety : 0.0005894875684610418
# N01 : 10056733 , N02 : 9555492 ; N11 : 187670, N12 : 173181
#  Asymmety : 0.0005374162452111177
# N01 : 10038616 , N02 : 9526278 ; N11 : 186935, N12 : 172147
#  Asymmety : 0.0005508396227312182
# N01 : 10062903 , N02 : 9543713 ; N11 : 188500, N12 : 173174
#  Asymmety : 0.0005868203662060013
# N01 : 10067635 , N02 : 9549622 ; N11 : 188916, N12 : 172776
#  Asymmety : 0.0006722411841875477
# ------1------
# minus
# N01 : 9505693 , N02 : 10021895 ; N11 : 174852, N12 : 183187
#  Asymmety : 0.00011577173497979293
# N01 : 9543087 , N02 : 10066675 ; N11 : 176067, N12 : 184552
#  Asymmety : 0.0001167253798967996
# N01 : 9546830 , N02 : 10064345 ; N11 : 175839, N12 : 185570
#  Asymmety : -1.9783840440195516e-05
# N01 : 9540146 , N02 : 10078276 ; N11 : 175102, N12 : 185597
# ...

# %% [markdown]
# it takes 12 seconds to get through the plus only for all the 6 foil position

# %%
for Ethr in np.arange(10,110, 20):
    plotFoilsAvg(
    df1 = plusZMylFoilBz1, df2 = plusZMylFoilBz6, Y1 = 'E1', Y2 = 'E2', tFirst='t1', tLast = 't2',
    EcutValue=Ethr,  detTrigg='E1', yMin1=0, yMin2=350, title = 'source facing +z Ethreshold = ', yLabel='Average Energy (keV)', i = 0, j = 5
)

# %%
#for z =1 
for Ethr in np.arange(10,110, 20):
    plotFoilsAvg(
    df1 = plusZMylFoilBz1, df2 = minusZMylFoilBz1, Y1 = 'E1', Y2 = 'E2', tFirst='t1', tLast = 't2',
    tFirst1='t2', tLast1 = 't1',detTrigg1='E2',
    EcutValue=Ethr,  detTrigg='E1', yMin1=0, yMin2=350, title = 'source facing diff direction Ethreshold = ', yLabel='Average Energy (keV)', i = 0, j = 2
)

# %%
#for z = 1.6 m 
for Ethr in np.arange(10,110, 20):
    plotFoilsAvg(
    df1 = plusZMylFoilBz6, df2 = minusZMylFoilBz6, Y1 = 'E1', Y2 = 'E2', tFirst='t1', tLast = 't2',
    tFirst1='t2', tLast1 = 't1',detTrigg1='E2',
    EcutValue=Ethr,  detTrigg='E1', yMin1=0, yMin2=350, title = 'source facing diff direction for foil at 1.6m Ethreshold = ', yLabel='Average Energy (keV)', i = 1, j = 4
)

# %%
plusBz
# Out:
# {'01':               E1       E2            t1            t2
#  0       147.4400  214.720  9.925100e-08  4.596970e-08
#  1       246.2660  108.031  1.005770e-07  4.752850e-08
#  2       240.6290  121.650  1.171060e-08  4.712730e-08
#  3        56.4189  329.873  9.353440e-08  5.908920e-08
#  4       209.9700  152.490  9.929150e-08  1.306420e-07
#  ...          ...      ...           ...           ...
#  361801  108.5630  275.260  9.929200e-08  5.069370e-08
#  361802  105.6840  276.795  2.145460e-07  1.601510e-07
#  361803   44.7015  311.118  2.319550e-07  1.268630e-07
#  361804  252.7790  100.574  6.344860e-08  4.195610e-08
#  361805  107.3380  254.899  4.226530e-08  1.454780e-08
#
#  [361806 rows x 4 columns],
#  '02':               E1        E2            t1            t2
#  0       201.5640  160.3260  7.256560e-08  3.573220e-08
#  1        94.3184  267.8360  5.172610e-08  1.294480e-08
#  2       172.2500   94.7361  1.493390e-08  7.266770e-08
# ...
